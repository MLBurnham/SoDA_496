# %% [markdown]
# # Welcome to Jupyter lab!
#
# Jupyter lab is an IDE commonly used in the data science field. It is most commonly used with python, but can also be used for working in R, Julia, and many other languages.
#
# Jupyter lab can launch markdown files, consoles, .py or .R files, and fancy notebooks like this.
#
# One of the best features of jupyter lab is its lightning fast .csv viewer.

# %% [markdown]
# Notebooks have two types of cells, markdown and code cells. Markdown cells use standard markdown notation and render when you run them.
#
# This is a list:
# - item 1
# - item 2
# - item 3
#
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# ~~strikethrough~~
#
# _Italics_
#
# **bold**Welcome

# %% [markdown]
# # Shortcuts

# %% [markdown]
# m: change cell to markdown mode
#
# y: change cell to code
#
# d+d: Delete a cell
#
# z: Undo cell deletion
#
# a: create a new cell above
#
# b: create a new cell below
#
# enter: begin typing in a cell
#
# esc: exit the cell you are currently working in
#
# ctrl+enter: Run cell

# %%
# You can also interact with the terminal in a notebook with the "!"
! conda env export > plsc496.yml

# %% [markdown]
# # Programming in Jupyter

# %%
# it's good to follow normal programming conventions. Use comments rather than markdown to comment code and place imports at the top of the notebook
import pandas as pd
import seaborn as sns

# %%
pokemon = pd.read_csv("pokemon.csv")

pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
sns.scatterplot(x = 'Attack', 
                y = 'Defense', 
                hue = 'Type 1', 
                data = pokemon[pokemon['Type 1'].isin(['Grass', 'Fire', 'Water'])],
                hue_order = ['Water', 'Fire', 'Grass']
               )

plt.show()
